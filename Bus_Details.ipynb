# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver import ActionChains
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import NoSuchElementException
import time
import pandas as pd

# %% [markdown]
# Andhra Buses

# %%
df_AP=pd.read_csv('df_Andhra.csv')
df_AP
# Out:
#                                  Route_name  \
# 0                   Hyderabad to Vijayawada
# 1                   Vijayawada to Hyderabad
# 2                       Hyderabad to Ongole
# 3                 Kakinada to Visakhapatnam
# 4                     Bangalore to Tirupati
# 5                       Bangalore to Kadapa
# 6                       Ongole to Hyderabad
# 7                       Kadapa to Bangalore
# 8    Chittoor (Andhra Pradesh) to Bangalore
# 9                 Visakhapatnam to Kakinada
# 10  Bangalore to Anantapur (andhra pradesh)
# 11   Bangalore to Chittoor (Andhra Pradesh)
# 12  Anantapur (andhra pradesh) to Bangalore
# 13                     Hyderabad to Kurnool
# 14                    Tirupati to Bangalore
# 15                Narasaraopet to Hyderabad
# 16                   Vinukonda to Hyderabad
# 17                   Hyderabad to Vinukonda
# 18              Visakhapatnam to Vijayawada
# 19                   Bangalore to Rayachoti
# ...

# %%
driver_AP = webdriver.Chrome()
Bus_names_AP = []
Bus_types_AP = []
Start_Time_AP = []
End_Time_AP = []
Ratings_AP = []
Total_Duration_AP = []
Prices_AP = []
Seats_Available_AP = []
Route_names = []
Route_links = []

for i,r in df_AP.iterrows():
    link=r["Route_link"]
    routes=r["Route_name"]

    driver_AP.get(link)
    time.sleep(2)  

    x = driver_AP.find_elements(By.XPATH, f"//a[contains(@href, '{link}')]")
    for j in x:
        j.click()
        time.sleep(2)

    try:
        click = driver_AP.find_element(By.XPATH, "//div[@class='button']")
        click.click()
    except:
        continue  
    time.sleep(2)
    
    scrolling = True
    while scrolling:
        old_page_source = driver_AP.page_source

        ActionChains(driver_AP).send_keys(Keys.PAGE_DOWN).perform()
        
        time.sleep(5)  
        
        new_page_source = driver_AP.page_source
        
        if new_page_source == old_page_source:
            scrolling = False

    bus_name = driver_AP.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type = driver_AP.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    start_time = driver_AP.find_elements(By.XPATH, "//*[@class='dp-time f-19 d-color f-bold']")
    end_time = driver_AP.find_elements(By.XPATH, "//*[@class='bp-time f-19 d-color disp-Inline']")
    total_duration = driver_AP.find_elements(By.XPATH, "//*[@class='dur l-color lh-24']")
    try:
        rating = driver_AP.find_elements(By.XPATH,"//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")
    except:
        continue
    price = driver_AP.find_elements(By.XPATH, '//*[@class="fare d-block"]')
    seats = driver_AP.find_elements(By.XPATH, "//div[contains(@class, 'seat-left')]")

    for bus in bus_name:
        Bus_names_AP.append(bus.text)
        Route_links.append(link)
        Route_names.append(routes)
    for bus_type_1 in bus_type:
        Bus_types_AP.append(bus_type_1.text)
    for start_time_1 in start_time:
        Start_Time_AP.append(start_time_1.text)
    for end_time_1 in end_time:
        End_Time_AP.append(end_time_1.text)
    for total_duration_1 in total_duration:
        Total_Duration_AP.append(total_duration_1.text)
    for ratings in rating:
        Ratings_AP.append(ratings.text)
    for price_1 in price:
        Prices_AP.append(price_1.text)
    for seats_1 in seats:
        Seats_Available_AP.append(seats_1.text)
        
print("Successfully Completed")
# Out:
# Successfully Completed

# %%
data_AP = {
    'Bus_name': Bus_names_AP,
    'Bus_type': Bus_types_AP,
    'Start_time': Start_Time_AP,
    'End_time': End_Time_AP,
    'Total_duration': Total_Duration_AP,
    'Price': Prices_AP,
    "Seats_Available":Seats_Available_AP,
    "Ratings":Ratings_AP,
    'Route_link': Route_links,
    'Route_name': Route_names
}

df_buses_AP = pd.DataFrame(data_AP)
path=r"C:\Users\bhara\Project\df_buses_AP.csv"
df_buses_AP.to_csv(path,index=False)

# %%
df_buses_AP
# Out:
#                 Bus_name                        Bus_type Start_time End_time  \
# 0               FRESHBUS       Electric A/C Seater (2+2)      05:50    11:45
# 1               FRESHBUS       Electric A/C Seater (2+2)      11:05    17:40
# 2        Sri KVR Travels               A/C Sleeper (2+1)      23:35    05:15
# 3    AdIntrCity SmartBus      A/C Seater / Sleeper (2+1)      00:15    06:25
# 4      IntrCity SmartBus      A/C Seater / Sleeper (2+1)      23:50    05:35
# ..                   ...                             ...        ...      ...
# 801         Indu Travels  Non A/C Seater / Sleeper (2+1)      22:00    04:30
# 802         Indu Travels  Non A/C Seater / Sleeper (2+1)      21:45    04:20
# 803          BRS Travels     NON AC Seater / Sleeper 2+1      22:30    05:00
# 804          AdSRI AVANI  Non A/C Seater / Sleeper (2+1)      21:10    04:30
# 805          BRS Travels               A/C Sleeper (2+1)      22:30    05:30
#
# ...

# %% [markdown]
# Kerala bus details

# %%
df_KL=pd.read_csv('df_Kerala.csv')
df_KL
# Out:
#                          Route_name  \
# 0            Bangalore to Kozhikode
# 1            Kozhikode to Bangalore
# 2            Kozhikode to Ernakulam
# 3            Ernakulam to Kozhikode
# 4               Bangalore to Kannur
# 5               Kozhikode to Mysore
# 6               Kannur to Bangalore
# 7   Kozhikode to Thiruvananthapuram
# 8               Mysore to Kozhikode
# 9    Bangalore to Kalpetta (kerala)
# 10   Kalpetta (kerala) to Bangalore
# 11  Thiruvananthapuram to Kozhikode
# 12            Kozhikode to Thrissur
# 13            Kozhikode to Kottayam
# 14            Kottayam to Kozhikode
#
#                                            Route_link
# 0   https://www.redbus.in/bus-tickets/bangalore-to...
# 1   https://www.redbus.in/bus-tickets/kozhikode-to...
# 2   https://www.redbus.in/bus-tickets/kozhikode-to...
# 3   https://www.redbus.in/bus-tickets/ernakulam-to...
# 4   https://www.redbus.in/bus-tickets/bangalore-to...
# ...

# %%
driver_KL = webdriver.Chrome()
Bus_names_KL = []
Bus_types_KL = []
Start_Time_KL = []
End_Time_KL = []
Ratings_KL = []
Total_Duration_KL = []
Prices_KL = []
Seats_Available_KL = []
Route_names = []
Route_links = []

for i,r in df_KL.iterrows():
    link=r["Route_link"]
    routes=r["Route_name"]

    driver_KL.get(link)
    time.sleep(2)  

    x = driver_KL.find_elements(By.XPATH, f"//a[contains(@href, '{link}')]")
    for j in x:
        j.click()
        time.sleep(2)

    try:
        click = driver_KL.find_element(By.XPATH, "//div[@class='button']")
        click.click()
    except:
        continue  
    time.sleep(2)
    
    scrolling = True
    while scrolling:
        old_page_source = driver_KL.page_source

        ActionChains(driver_KL).send_keys(Keys.PAGE_DOWN).perform()
        
        time.sleep(5)  
        
        new_page_source = driver_KL.page_source
        
        if new_page_source == old_page_source:
            scrolling = False

    bus_name = driver_KL.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type = driver_KL.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    start_time = driver_KL.find_elements(By.XPATH, "//*[@class='dp-time f-19 d-color f-bold']")
    end_time = driver_KL.find_elements(By.XPATH, "//*[@class='bp-time f-19 d-color disp-Inline']")
    total_duration = driver_KL.find_elements(By.XPATH, "//*[@class='dur l-color lh-24']")
    try:
        rating = driver_KL.find_elements(By.XPATH,"//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")
    except:
        continue
    price = driver_KL.find_elements(By.XPATH, '//*[@class="fare d-block"]')
    seats = driver_KL.find_elements(By.XPATH, "//div[contains(@class, 'seat-left')]")

    for bus in bus_name:
        Bus_names_KL.append(bus.text)
        Route_links.append(link)
        Route_names.append(routes)
    for bus_type_1 in bus_type:
        Bus_types_KL.append(bus_type_1.text)
    for start_time_1 in start_time:
        Start_Time_KL.append(start_time_1.text)
    for end_time_1 in end_time:
        End_Time_KL.append(end_time_1.text)
    for total_duration_1 in total_duration:
        Total_Duration_KL.append(total_duration_1.text)
    for ratings in rating:
        Ratings_KL.append(ratings.text)
    for price_1 in price:
        Prices_KL.append(price_1.text)
    for seats_1 in seats:
        Seats_Available_KL.append(seats_1.text)
        
print("Successfully Completed")
# Out:
# Successfully Completed

# %%
data_KL = {
    'Bus_name': Bus_names_KL,
    'Bus_type': Bus_types_KL,
    'Start_time': Start_Time_KL,
    'End_time': End_Time_KL,
    'Total_duration': Total_Duration_KL,
    'Price': Prices_KL,
    "Seats_Available":Seats_Available_KL,
    "Ratings":Ratings_KL,
    'Route_link': Route_links,
    'Route_name': Route_names
}

df_buses_KL = pd.DataFrame(data_KL)
path=r"C:\Users\bhara\Project\df_buses_KL.csv"
df_buses_KL.to_csv(path,index=False)

# %%
df_buses_KL
# Out:
#                   Bus_name                                          Bus_type  \
# 0     KSRTC (Kerala) - 581         Super Express Non AC Seater Air Bus (2+2)
# 1      KSRTC (Kerala) - 52                       SWIFT-GARUDA A/C SEATER BUS
# 2    KSRTC (Kerala) - 1378                                     AC MULTI AXLE
# 3     KSRTC (Kerala) - 129                       SWIFT-GARUDA A/C SEATER BUS
# 4     KSRTC (Kerala) - 235                 Swift Deluxe Non AC Air Bus (2+2)
# ..                     ...                                               ...
# 294          Sonia Travels                          A/C Seater/Sleeper (2+1)
# 295        Madhavi Travels                                 A/C Sleeper (2+1)
# 296        Madhavi Travels  Volvo Multi-Axle I-Shift B11R Semi Sleeper (2+2)
# 297            Ubc travels                          A/C Seater/Sleeper (2+1)
# 298            Ubc travels                            A/C Semi Sleeper (2+2)
#
# ...

# %% [markdown]
# Telangana Bus details

# %%
df_TL=pd.read_csv('df_Telangana.csv')
df_TL
# Out:
#                               Route_name  \
# 0                  Hyderabad to Tirupati
# 1             Hyderabad to Godavarikhani
# 2                    Hyderabad to Armoor
# 3                   Hyderabad to Nandyal
# 4                     Hyderabad to Kodad
# 5                   Hyderabad to Addanki
# 6                Kothagudem to Hyderabad
# 7   Guntur (Andhra Pradesh) to Hyderabad
# 8   Hyderabad to Guntur (Andhra Pradesh)
# 9             Godavarikhani to Hyderabad
# 10               Hyderabad to Kothagudem
# 11               Hyderabad to Sathupally
# 12                 Hyderabad to Warangal
# 13                    Kodad to Hyderabad
# 14                 Jagityal to Hyderabad
# 15             Hyderabad to Bhadrachalam
# 16                 Hyderabad to Tirupati
# 17            Hyderabad to Godavarikhani
# 18                   Hyderabad to Armoor
# 19                  Hyderabad to Nandyal
# 20                    Hyderabad to Kodad
# 21                  Hyderabad to Addanki
#
# ...

# %%
driver_TL = webdriver.Chrome()
Bus_names_TL = []
Bus_types_TL = []
Start_Time_TL = []
End_Time_TL = []
Ratings_TL = []
Total_Duration_TL = []
Prices_TL = []
Seats_Available_TL = []
Route_names = []
Route_links = []

for i,r in df_TL.iterrows():
    link=r["Route_link"]
    routes=r["Route_name"]

    driver_TL.get(link)
    time.sleep(2)  

    x = driver_TL.find_elements(By.XPATH, f"//a[contains(@href, '{link}')]")
    for j in x:
        j.click()
        time.sleep(2)

    try:
        click = driver_TL.find_element(By.XPATH, "//div[@class='button']")
        click.click()
    except:
        continue  
    time.sleep(2)
    
    scrolling = True
    while scrolling:
        old_page_source = driver_TL.page_source

        ActionChains(driver_TL).send_keys(Keys.PAGE_DOWN).perform()
        
        time.sleep(5)  
        
        new_page_source = driver_TL.page_source
        
        if new_page_source == old_page_source:
            scrolling = False

    bus_name = driver_TL.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type = driver_TL.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    start_time = driver_TL.find_elements(By.XPATH, "//*[@class='dp-time f-19 d-color f-bold']")
    end_time = driver_TL.find_elements(By.XPATH, "//*[@class='bp-time f-19 d-color disp-Inline']")
    total_duration = driver_TL.find_elements(By.XPATH, "//*[@class='dur l-color lh-24']")
    try:
        rating = driver_TL.find_elements(By.XPATH,"//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")
    except:
        continue
    price = driver_TL.find_elements(By.XPATH, '//*[@class="fare d-block"]')
    seats = driver_TL.find_elements(By.XPATH, "//div[contains(@class, 'seat-left')]")

    for bus in bus_name:
        Bus_names_TL.append(bus.text)
        Route_links.append(link)
        Route_names.append(routes)
    for bus_type_1 in bus_type:
        Bus_types_TL.append(bus_type_1.text)
    for start_time_1 in start_time:
        Start_Time_TL.append(start_time_1.text)
    for end_time_1 in end_time:
        End_Time_TL.append(end_time_1.text)
    for total_duration_1 in total_duration:
        Total_Duration_TL.append(total_duration_1.text)
    for ratings in rating:
        Ratings_TL.append(ratings.text)
    for price_1 in price:
        Prices_TL.append(price_1.text)
    for seats_1 in seats:
        Seats_Available_TL.append(seats_1.text)
        
print("Successfully Completed")
# Out:
# Successfully Completed

# %%
data_TL = {
    'Bus_name': Bus_names_TL,
    'Bus_type': Bus_types_TL,
    'Start_time': Start_Time_TL,
    'End_time': End_Time_TL,
    'Total_duration': Total_Duration_TL,
    'Price': Prices_TL,
    "Seats_Available":Seats_Available_TL,
    "Ratings":Ratings_TL,
    'Route_link': Route_links,
    'Route_name': Route_names
}

df_buses_TL = pd.DataFrame(data_TL)
path=r"C:\Users\bhara\Project\df_buses_TL.csv"
df_buses_TL.to_csv(path,index=False)

# %%
df_buses_TL
# Out:
#                 Bus_name                                    Bus_type  \
# 0          TGSRTC - 2085  Super Luxury (Non AC Seater 2+2 Push Back)
# 1          TGSRTC - 4457  Super Luxury (Non AC Seater 2+2 Push Back)
# 2          TGSRTC - 1711  Super Luxury (Non AC Seater 2+2 Push Back)
# 3          TGSRTC - 7452  Super Luxury (Non AC Seater 2+2 Push Back)
# 4          TGSRTC - 9595                          Lahari A/C sleeper
# ..                   ...                                         ...
# 435         KMBT Travels             NON A/C Hi-Tech Push Back (2+2)
# 436      Vihari Travels               Non A/C Seater / Sleeper (2+1)
# 437     V Kaveri Travels                           A/C Sleeper (2+1)
# 438  Sri Krishna Travels            A/C Semi Sleeper / Sleeper (2+1)
# 439         Mozo travels                           A/C Sleeper (2+1)
#
#     Start_time End_time Total_duration     Price     Seats_Available  Ratings  \
# ...

# %% [markdown]
# Kadamba bus details

# %%
df_KD=pd.read_csv('df_Kadamba.csv')
df_KD
# Out:
#                          Route_name  \
# 0                       Pune to Goa
# 1                       Goa to Pune
# 2                     Mumbai to Goa
# 3                  Bangalore to Goa
# 4                  Goa to Bangalore
# 5                     Goa to Mumbai
# 6                 Pandharpur to Goa
# 7                 Goa to Pandharpur
# 8                    Solapur to Goa
# 9    Calangute (goa) to Goa Airport
# 10     Goa to Kolhapur(Maharashtra)
# 11                   Goa to Solapur
# 12                    Goa to Sangli
# 13   Goa Airport to Calangute (goa)
# 14         Goa to Sangola (Solapur)
# 15         Sangola (Solapur) to Goa
# 16  Mopa Airport to Calangute (goa)
# 17  Calangute (goa) to Mopa Airport
# 18              Goa to Mopa Airport
# 19                     Goa to Miraj
# 20            Panaji to Goa Airport
# 21              Mopa Airport to Goa
# 22                Shivamogga to Goa
# 23           Margao to Mopa Airport
# 24               Goa Airport to Goa
# ...

# %%
driver_KD = webdriver.Chrome()
Bus_names_KD = []
Bus_types_KD = []
Start_Time_KD = []
End_Time_KD = []
Ratings_KD = []
Total_Duration_KD = []
Prices_KD = []
Seats_Available_KD = []
Route_names = []
Route_links = []

for i,r in df_KD.iterrows():
    link=r["Route_link"]
    routes=r["Route_name"]

    driver_KD.get(link)
    time.sleep(2)  

    x = driver_KD.find_elements(By.XPATH, f"//a[contains(@href, '{link}')]")
    for j in x:
        j.click()
        time.sleep(2)

    # try:
    #     click = driver_KD.find_element(By.XPATH, "//div[@class='button']")
    #     click.click()
    # except:
    #     continue  
    # time.sleep(2)
    
    scrolling = True
    while scrolling:
        old_page_source = driver_KD.page_source

        ActionChains(driver_KD).send_keys(Keys.PAGE_DOWN).perform()
        
        time.sleep(5)  
        
        new_page_source = driver_KD.page_source
        
        if new_page_source == old_page_source:
            scrolling = False

    bus_name = driver_KD.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type = driver_KD.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    start_time = driver_KD.find_elements(By.XPATH, "//*[@class='dp-time f-19 d-color f-bold']")
    end_time = driver_KD.find_elements(By.XPATH, "//*[@class='bp-time f-19 d-color disp-Inline']")
    total_duration = driver_KD.find_elements(By.XPATH, "//*[@class='dur l-color lh-24']")
    try:
        rating = driver_KD.find_elements(By.XPATH,"//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")
    except:
        continue
    price = driver_KD.find_elements(By.XPATH, '//*[@class="fare d-block"]')
    seats = driver_KD.find_elements(By.XPATH, "//div[contains(@class, 'seat-left')]")

    for bus in bus_name:
        Bus_names_KD.append(bus.text)
        Route_links.append(link)
        Route_names.append(routes)
    for bus_type_1 in bus_type:
        Bus_types_KD.append(bus_type_1.text)
    for start_time_1 in start_time:
        Start_Time_KD.append(start_time_1.text)
    for end_time_1 in end_time:
        End_Time_KD.append(end_time_1.text)
    for total_duration_1 in total_duration:
        Total_Duration_KD.append(total_duration_1.text)
    for ratings in rating:
        Ratings_KD.append(ratings.text)
    for price_1 in price:
        Prices_KD.append(price_1.text)
    for seats_1 in seats:
        Seats_Available_KD.append(seats_1.text)
        
print("Successfully Completed")
# Out:
# Successfully Completed

# %%
data_KD = {
    'Bus_name': Bus_names_KD,
    'Bus_type': Bus_types_KD,
    'Start_time': Start_Time_KD,
    'End_time': End_Time_KD,
    'Total_duration': Total_Duration_KD,
    'Price': Prices_KD,
    "Seats_Available":Seats_Available_KD,
    "Ratings":Ratings_KD,
    'Route_link': Route_links,
    'Route_name': Route_names
}

df_buses_KD = pd.DataFrame(data_KD)
path=r"C:\Users\bhara\Project\df_buses_KD.csv"
df_buses_KD.to_csv(path,index=False)

# %%
df_buses_KD
# Out:
#                                               Bus_name  \
# 0    Kadamba Transport Corporation Limited (KTCL) -...
# 1                                    IntrCity SmartBus
# 2                                    IntrCity SmartBus
# 3                                       AdZingbus Plus
# 4                                      Ashray Amrutyog
# ..                                                 ...
# 200  Kadamba Transport Corporation Limited (KTCL) -...
# 201                                   Sea Bird Tourist
# 202  Kadamba Transport Corporation Limited (KTCL) -...
# 203  Kadamba Transport Corporation Limited (KTCL) -...
# 204                                        S R Travels
#
#                                   Bus_type Start_time End_time Total_duration  \
# 0                        A/C Sleeper (2+1)      19:15    05:50        10h 35m
# 1    Bharat Benz A/C Seater /Sleeper (2+1)      21:00    08:05        11h 05m
# ...

# %% [markdown]
# Rajasthan Bus Details

# %%
df_RJ = pd.read_csv('df_Rajasthan.csv')
df_RJ
# Out:
#                                        Route_name  \
# 0                              Udaipur to Jodhpur
# 1                                Jodhpur to Ajmer
# 2        Beawar (Rajasthan) to Jaipur (Rajasthan)
# 3                     Sikar to Jaipur (Rajasthan)
# 4                   Jaipur (Rajasthan) to Jodhpur
# 5   Aligarh (uttar pradesh) to Jaipur (Rajasthan)
# 6   Jaipur (Rajasthan) to Aligarh (uttar pradesh)
# 7                   Jodhpur to Beawar (Rajasthan)
# 8                    Jaipur (Rajasthan) to Pilani
# 9                Kishangarh to Jaipur (Rajasthan)
# 10                    Pali (Rajasthan) to Udaipur
# 11                    Udaipur to Pali (Rajasthan)
# 12                     Kota(Rajasthan) to Udaipur
# 13                 Jaipur (Rajasthan) to Bhilwara
# 14                               Sikar to Bikaner
# 15                Jaipur (Rajasthan) to Bharatpur
# 16                  Jaipur (Rajasthan) to Mathura
# 17          Jaipur (Rajasthan) to Kota(Rajasthan)
#
# ...

# %%
driver_RJ = webdriver.Chrome()
Bus_names_RJ = []
Bus_types_RJ = []
Start_Time_RJ = []
End_Time_RJ = []
Ratings_RJ = []
Total_Duration_RJ = []
Prices_RJ = []
Seats_Available_RJ = []
Route_names = []
Route_links = []

for i,r in df_RJ.iterrows():
    link=r["Route_link"]
    routes=r["Route_name"]

    driver_RJ.get(link)
    time.sleep(2)  

    x = driver_RJ.find_elements(By.XPATH, f"//a[contains(@href, '{link}')]")
    for j in x:
        j.click()
        time.sleep(2)

    try:
        click = driver_RJ.find_element(By.XPATH, "//div[@class='button']")
        click.click()
    except:
        continue  
    time.sleep(2)
    
    scrolling = True
    while scrolling:
        old_page_source = driver_RJ.page_source

        ActionChains(driver_RJ).send_keys(Keys.PAGE_DOWN).perform()
        
        time.sleep(5)  
        
        new_page_source = driver_RJ.page_source
        
        if new_page_source == old_page_source:
            scrolling = False

    bus_name = driver_RJ.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type = driver_RJ.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    start_time = driver_RJ.find_elements(By.XPATH, "//*[@class='dp-time f-19 d-color f-bold']")
    end_time = driver_RJ.find_elements(By.XPATH, "//*[@class='bp-time f-19 d-color disp-Inline']")
    total_duration = driver_RJ.find_elements(By.XPATH, "//*[@class='dur l-color lh-24']")
    try:
        rating = driver_RJ.find_elements(By.XPATH,"//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")
    except:
        continue
    price = driver_RJ.find_elements(By.XPATH, '//*[@class="fare d-block"]')
    seats = driver_RJ.find_elements(By.XPATH, "//div[contains(@class, 'seat-left')]")

    for bus in bus_name:
        Bus_names_RJ.append(bus.text)
        Route_links.append(link)
        Route_names.append(routes)
    for bus_type_1 in bus_type:
        Bus_types_RJ.append(bus_type_1.text)
    for start_time_1 in start_time:
        Start_Time_RJ.append(start_time_1.text)
    for end_time_1 in end_time:
        End_Time_RJ.append(end_time_1.text)
    for total_duration_1 in total_duration:
        Total_Duration_RJ.append(total_duration_1.text)
    for ratings in rating:
        Ratings_RJ.append(ratings.text)
    for price_1 in price:
        Prices_RJ.append(price_1.text)
    for seats_1 in seats:
        Seats_Available_RJ.append(seats_1.text)
        
print("Successfully Completed")
# Out:
# Successfully Completed

# %%
data_RJ = {
    'Bus_name': Bus_names_RJ,
    'Bus_type': Bus_types_RJ,
    'Start_time': Start_Time_RJ,
    'End_time': End_Time_RJ,
    'Total_duration': Total_Duration_RJ,
    'Price': Prices_RJ,
    "Seats_Available":Seats_Available_RJ,
    "Ratings":Ratings_RJ,
    'Route_link': Route_links,
    'Route_name': Route_names
}

df_buses_RJ = pd.DataFrame(data_RJ)
path=r"C:\Users\bhara\Project\df_buses_RJ.csv"
df_buses_RJ.to_csv(path,index=False)

# %%
df_buses_RJ
# Out:
#                        Bus_name                                   Bus_type  \
# 0                RSRTC - 157455  Super Luxury Volvo AC Seater Pushback 2+2
# 1                RSRTC - 190571                  Express Non AC Seater 2+3
# 2                RSRTC - 188046                  Express Non AC Seater 2+3
# 3                RSRTC - 167049                  Express Non AC Seater 2+3
# 4                RSRTC - 146140  Super Luxury Volvo AC Seater Pushback 2+2
# ..                          ...                                        ...
# 315              Jakhar Travels                 A/C Seater / Sleeper (2+1)
# 316       Raj travels Jhunjhunu                 A/C Seater / Sleeper (2+1)
# 317                Babu Travels             Non A/C Seater / Sleeper (2+1)
# 318         Sethi Yatra Company              NON A/C Seater/ Sleeper (2+1)
# 319  Jai Shrinath Ji Ki Travels             Non A/C Seater / Sleeper (2+1)
#
# ...

# %% [markdown]
# South Bengal Bus details

# %%
df_SB = pd.read_csv('df_South_Bengal.csv')
df_SB
# Out:
#                                            Route_name  \
# 0                                Durgapur to Calcutta
# 1                                  Kolkata to Burdwan
# 2                                  Haldia to Calcutta
# 3                                   Kolkata to Haldia
# 4                   Kolkata to Durgapur (West Bengal)
# 5                   Kolkata to Arambagh (West Bengal)
# 6                                Midnapore to Kolkata
# 7                                    Kolkata to Digha
# 8                                   Digha to Calcutta
# 9                                  Kolkata to Bankura
# 10                               Kolkata to Midnapore
# 11                   Kolkata to Asansol (West Bengal)
# 12                                Kolkata to Nimtouri
# 13                                Jhargram to Kolkata
# 14                         Kolkata to Contai (Kanthi)
# 15                                Kolkata to Kolaghat
# ...

# %%
driver_SB = webdriver.Chrome()
Bus_names_SB = []
Bus_types_SB = []
Start_Time_SB = []
End_Time_SB = []
Ratings_SB = []
Total_Duration_SB = []
Prices_SB = []
Seats_Available_SB = []
Route_names = []
Route_links = []

for i,r in df_SB.iterrows():
    link=r["Route_link"]
    routes=r["Route_name"]

    driver_SB.get(link)
    time.sleep(2)  

    x = driver_SB.find_elements(By.XPATH, f"//a[contains(@href, '{link}')]")
    for j in x:
        j.click()
        time.sleep(2)

    try:
        click = driver_SB.find_element(By.XPATH, "//div[@class='button']")
        click.click()
    except:
        continue  
    time.sleep(2)
    
    scrolling = True
    while scrolling:
        old_page_source = driver_SB.page_source

        ActionChains(driver_SB).send_keys(Keys.PAGE_DOWN).perform()
        
        time.sleep(3)  
        
        new_page_source = driver_SB.page_source
        
        if new_page_source == old_page_source:
            scrolling = False

    bus_name = driver_SB.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type = driver_SB.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    start_time = driver_SB.find_elements(By.XPATH, "//*[@class='dp-time f-19 d-color f-bold']")
    end_time = driver_SB.find_elements(By.XPATH, "//*[@class='bp-time f-19 d-color disp-Inline']")
    total_duration = driver_SB.find_elements(By.XPATH, "//*[@class='dur l-color lh-24']")
    try:
        rating = driver_SB.find_elements(By.XPATH,"//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")
    except:
        continue
    price = driver_SB.find_elements(By.XPATH, '//*[@class="fare d-block"]')
    seats = driver_SB.find_elements(By.XPATH, "//div[contains(@class, 'seat-left')]")

    for bus in bus_name:
        Bus_names_SB.append(bus.text)
        Route_links.append(link)
        Route_names.append(routes)
    for bus_type_1 in bus_type:
        Bus_types_SB.append(bus_type_1.text)
    for start_time_1 in start_time:
        Start_Time_SB.append(start_time_1.text)
    for end_time_1 in end_time:
        End_Time_SB.append(end_time_1.text)
    for total_duration_1 in total_duration:
        Total_Duration_SB.append(total_duration_1.text)
    for ratings in rating:
        Ratings_SB.append(ratings.text)
    for price_1 in price:
        Prices_SB.append(price_1.text)
    for seats_1 in seats:
        Seats_Available_SB.append(seats_1.text)
        
print("Successfully Completed")
# Out:
# Successfully Completed

# %%
data_SB = {
    'Bus_name': Bus_names_SB,
    'Bus_type': Bus_types_SB,
    'Start_time': Start_Time_SB,
    'End_time': End_Time_SB,
    'Total_duration': Total_Duration_SB,
    'Price': Prices_SB,
    "Seats_Available":Seats_Available_SB,
    "Ratings":Ratings_SB,
    'Route_link': Route_links,
    'Route_name': Route_names
}

df_buses_SB = pd.DataFrame(data_SB)
path=r"C:\Users\bhara\Project\df_buses_SB.csv"
df_buses_SB.to_csv(path,index=False)

# %%
df_buses_SB
# Out:
#                                               Bus_name  \
# 0    SBSTC-KOLKATA - BURDWAN - 12:35 (BWN DEPOT) - ...
# 1    SBSTC-KARUNAMOYEE - BURDWAN - 13:00 (KALNA DEP...
# 2    SBSTC-KARUNAMOYEE - BURDWAN - 13:30 (BWN DEPOT...
# 3    SBSTC-KARUNAMOYEE - BURDWAN - 14:00 (BWN DEPOT...
# 4     SBSTC-KOLKATA - BURDWAN - 14:00 (BWN DEPOT) - 83
# ..                                                 ...
# 241  SBSTC-DURGAPUR - MANBAZAR - 14:45 (MAN BZR) - ...
# 242  SBSTC-KOLKATA - PURULIA - VIA - BANKURA - 13:0...
# 243  SBSTC-DURGAPUR - MANBAZAR - 16:10 (MAN BZR) - ...
# 244                          Dolphin tours and travels
# 245                               Sri Balaji Parivahan
#
#                        Bus_type Start_time End_time Total_duration    Price  \
# 0           Non AC Seater (2+3)      12:35    14:35        02h 00m   INR 95
# 1           Non AC Seater (2+3)      13:00    15:00        02h 00m  INR 100
# ...

# %% [markdown]
# Himachal Bus details

# %%
df_HM = pd.read_csv('df_Himachal.csv')
df_HM
# Out:
#                                       Route_name  \
# 0                                Delhi to Shimla
# 1      Chandigarh to Hamirpur (Himachal Pradesh)
# 2      Hamirpur (Himachal Pradesh) to Chandigarh
# 3                                Shimla to Delhi
# 4                            Delhi to Chandigarh
# 5           Hamirpur (Himachal Pradesh) to Delhi
# 6        Chamba (Himachal Pradesh) to Chandigarh
# 7           Delhi to Hamirpur (Himachal Pradesh)
# 8   Chandigarh to Dharamshala (Himachal Pradesh)
# 9             Delhi to Chamba (Himachal Pradesh)
# 10            Chamba (Himachal Pradesh) to Delhi
# 11                          Kangra to Chandigarh
# 12                          Shimla to Chandigarh
# 13             Delhi to Baddi (Himachal Pradesh)
# 14                                Delhi to Solan
# 15                             Delhi to Nalagarh
# 16  Dharamshala (Himachal Pradesh) to Chandigarh
# 17                        Palampur to Chandigarh
# ...

# %%
driver_HM = webdriver.Chrome()
Bus_names_HM = []
Bus_types_HM = []
Start_Time_HM = []
End_Time_HM = []
Ratings_HM = []
Total_Duration_HM = []
Prices_HM = []
Seats_Available_HM = []
Route_names = []
Route_links = []

for i,r in df_HM.iterrows():
    link=r["Route_link"]
    routes=r["Route_name"]

    driver_HM.get(link)
    time.sleep(2)  

    x = driver_HM.find_elements(By.XPATH, f"//a[contains(@href, '{link}')]")
    for j in x:
        j.click()
        time.sleep(2)

    try:
        click = driver_HM.find_element(By.XPATH, "//div[@class='button']")
        click.click()
    except:
        continue  
    time.sleep(2)
    
    scrolling = True
    while scrolling:
        old_page_source = driver_HM.page_source

        ActionChains(driver_HM).send_keys(Keys.PAGE_DOWN).perform()
        
        time.sleep(3)  
        
        new_page_source = driver_HM.page_source
        
        if new_page_source == old_page_source:
            scrolling = False

    bus_name = driver_HM.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type = driver_HM.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    start_time = driver_HM.find_elements(By.XPATH, "//*[@class='dp-time f-19 d-color f-bold']")
    end_time = driver_HM.find_elements(By.XPATH, "//*[@class='bp-time f-19 d-color disp-Inline']")
    total_duration = driver_HM.find_elements(By.XPATH, "//*[@class='dur l-color lh-24']")
    try:
        rating = driver_HM.find_elements(By.XPATH,"//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")
    except:
        continue
    price = driver_HM.find_elements(By.XPATH, '//*[@class="fare d-block"]')
    seats = driver_HM.find_elements(By.XPATH, "//div[contains(@class, 'seat-left')]")

    for bus in bus_name:
        Bus_names_HM.append(bus.text)
        Route_links.append(link)
        Route_names.append(routes)
    for bus_type_1 in bus_type:
        Bus_types_HM.append(bus_type_1.text)
    for start_time_1 in start_time:
        Start_Time_HM.append(start_time_1.text)
    for end_time_1 in end_time:
        End_Time_HM.append(end_time_1.text)
    for total_duration_1 in total_duration:
        Total_Duration_HM.append(total_duration_1.text)
    for ratings in rating:
        Ratings_HM.append(ratings.text)
    for price_1 in price:
        Prices_HM.append(price_1.text)
    for seats_1 in seats:
        Seats_Available_HM.append(seats_1.text)
        
print("Successfully Completed")
# Out:
# Successfully Completed

# %%
data_HM = {
    'Bus_name': Bus_names_HM,
    'Bus_type': Bus_types_HM,
    'Start_time': Start_Time_HM,
    'End_time': End_Time_HM,
    'Total_duration': Total_Duration_HM,
    'Price': Prices_HM,
    "Seats_Available":Seats_Available_HM,
    "Ratings":Ratings_HM,
    'Route_link': Route_links,
    'Route_name': Route_names
}

df_buses_HM = pd.DataFrame(data_HM)
path=r"C:\Users\bhara\Project\df_buses_HM.csv"
df_buses_HM.to_csv(path,index=False)

# %%
df_buses_HM
# Out:
#                 Bus_name                                  Bus_type Start_time  \
# 0             HRTC - 551                       A/C Executive (2+3)      15:30
# 1             HRTC - 525                Ordinary 3+2 Non AC Seater      16:50
# 2             HRTC - 532                Ordinary 3+2 Non AC Seater      17:59
# 3             HRTC - 538                Ordinary 3+2 Non AC Seater      18:31
# 4              HRTC - 93        Himsuta AC Seater Volvo/Scania 2+2      19:35
# ..                   ...                                       ...        ...
# 399       Laxmi holidays         Volvo 9600 A/C Semi Sleeper (2+2)      16:00
# 400       Malana Travels  Volvo 9600 Multi Axle Semi-Sleeper (2+2)      20:00
# 401       Laxmi holidays         Volvo 9600 A/C Semi Sleeper (2+2)      21:30
# 402  AdIntrCity SmartBus         Volvo 9600 A/C Semi Sleeper (2+2)      17:00
# 403   Ram Dalal Holidays         Volvo 9600 A/C Semi Sleeper (2+2)      19:00
#
# ...

# %% [markdown]
# Assam bus details

# %%
df_AS = pd.read_csv('df_Assam.csv')
df_AS
# Out:
#                              Route_name  \
# 0                    Tezpur to Guwahati
# 1                    Guwahati to Tezpur
# 2            Guwahati to Nagaon (Assam)
# 3            Nagaon (Assam) to Guwahati
# 4                  Goalpara to Guwahati
# 5             Jorhat to North Lakhimpur
# 6                    Dhubri to Guwahati
# 7                   Jorhat to Dibrugarh
# 8             North Lakhimpur to Jorhat
# 9           North Lakhimpur to Sibsagar
# 10                   Guwahati to Dhubri
# 11               Dhekiajuli to Guwahati
# 12          Sibsagar to North Lakhimpur
# 13                  Dibrugarh to Jorhat
# 14                    Jorhat to Dhemaji
# 15                   Jorhat to Tinsukia
# 16                  Tezpur to Dibrugarh
# 17                    Dhemaji to Jorhat
# 18            North Lakhimpur to Tezpur
# 19        Guwahati to Biswanath Charali
# 20         North Lakhimpur to Dibrugarh
# 21                   Tinsukia to Jorhat
# ...

# %%
driver_AS = webdriver.Chrome()
Bus_names_AS = []
Bus_types_AS = []
Start_Time_AS = []
End_Time_AS = []
Ratings_AS = []
Total_Duration_AS = []
Prices_AS = []
Seats_Available_AS = []
Route_names = []
Route_links = []

for i,r in df_AS.iterrows():
    link=r["Route_link"]
    routes=r["Route_name"]

    driver_AS.get(link)
    time.sleep(2)  

    x = driver_AS.find_elements(By.XPATH, f"//a[contains(@href, '{link}')]")
    for j in x:
        j.click()
        time.sleep(2)

    # scrolling = True
    # while scrolling:
    #     old_page_source = driver_AS.page_source

    #     ActionChains(driver_AS).send_keys(Keys.PAGE_DOWN).perform()
        
    #     time.sleep(3)  
        
    #     new_page_source = driver_AS.page_source
        
    #     if new_page_source == old_page_source:
    #         scrolling = False

    bus_name = driver_AS.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type = driver_AS.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    start_time = driver_AS.find_elements(By.XPATH, "//*[@class='dp-time f-19 d-color f-bold']")
    end_time = driver_AS.find_elements(By.XPATH, "//*[@class='bp-time f-19 d-color disp-Inline']")
    total_duration = driver_AS.find_elements(By.XPATH, "//*[@class='dur l-color lh-24']")
    try:
        rating = driver_AS.find_elements(By.XPATH,"//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")
    except:
        continue
    price = driver_AS.find_elements(By.XPATH, '//*[@class="fare d-block"]')
    seats = driver_AS.find_elements(By.XPATH, "//div[contains(@class, 'seat-left')]")

    for bus in bus_name:
        Bus_names_AS.append(bus.text)
        Route_links.append(link)
        Route_names.append(routes)
    for bus_type_1 in bus_type:
        Bus_types_AS.append(bus_type_1.text)
    for start_time_1 in start_time:
        Start_Time_AS.append(start_time_1.text)
    for end_time_1 in end_time:
        End_Time_AS.append(end_time_1.text)
    for total_duration_1 in total_duration:
        Total_Duration_AS.append(total_duration_1.text)
    for ratings in rating:
        Ratings_AS.append(ratings.text)
    for price_1 in price:
        Prices_AS.append(price_1.text)
    for seats_1 in seats:
        Seats_Available_AS.append(seats_1.text)
        
print("Successfully Completed")
# Out:
# Successfully Completed

# %%
data_AS = {
    'Bus_name': Bus_names_AS,
    'Bus_type': Bus_types_AS,
    'Start_time': Start_Time_AS,
    'End_time': End_Time_AS,
    'Total_duration': Total_Duration_AS,
    'Price': Prices_AS,
    "Seats_Available":Seats_Available_AS,
    "Ratings":Ratings_AS,
    'Route_link': Route_links,
    'Route_name': Route_names
}

df_buses_AS = pd.DataFrame(data_AS)
path=r"C:\Users\bhara\Project\df_buses_AS.csv"
df_buses_AS.to_csv(path,index=False)

# %%
df_buses_AS
# Out:
#                             Bus_name  \
# 0               Chartered Bus - ASTC
# 1               Chartered Bus - ASTC
# 2                     SHIVAM TRAVELS
# 3               Chartered Bus - ASTC
# 4    BLUE HILL TRAVELS INDIA LIMITED
# ..                               ...
# 107                 NAMBOR TRANSPORT
# 108                 NAMBOR TRANSPORT
# 109              RATNAGIRI TRANSPORT
# 110              RATNAGIRI TRANSPORT
# 111                  Air Bus Travels
#
#                                              Bus_type Start_time End_time  \
# 0    Volvo Multi-Axle I-Shift B11R Semi Sleeper (2+2)      13:30    17:00
# 1                        Volvo AC Seater Pushback 2+2      14:30    18:30
# 2                        Bharat Benz A/C Seater (2+1)      15:00    19:15
# 3                        Volvo AC Seater Pushback 2+2      15:30    19:15
# 4                   NON A/C Seater Semi Sleeper (2+1)      22:15    03:45
# ...

# %% [markdown]
# UP bus details

# %%
df_UP = pd.read_csv('df_UP.csv')
df_UP
# Out:
#                                            Route_name  \
# 0                                   Delhi to Bareilly
# 1                                   Bareilly to Delhi
# 2                    Aligarh (uttar pradesh) to Delhi
# 3                    Delhi to Aligarh (uttar pradesh)
# 4                                Lucknow to Allahabad
# 5                                    Lucknow to Delhi
# 6                Delhi to Farrukhabad (Uttar Pradesh)
# 7                Farrukhabad (Uttar Pradesh) to Delhi
# 8                                     Badaun to Delhi
# 9                                Allahabad to Lucknow
# 10                                    Lucknow to Agra
# 11                   Sitapur (Uttar Pradesh) to Delhi
# 12                                    Delhi to Badaun
# 13                   Delhi to Sitapur (Uttar Pradesh)
# 14                                      Agra to Delhi
# 15                                 Delhi to Moradabad
# ...

# %%
driver_UP = webdriver.Chrome()
Bus_names_UP = []
Bus_types_UP = []
Start_Time_UP = []
End_Time_UP = []
Ratings_UP = []
Total_Duration_UP = []
Prices_UP = []
Seats_Available_UP = []
Route_names = []
Route_links = []

for i,r in df_UP.iterrows():
    link=r["Route_link"]
    routes=r["Route_name"]

    driver_UP.get(link)
    time.sleep(2)  

    x = driver_UP.find_elements(By.XPATH, f"//a[contains(@href, '{link}')]")
    for j in x:
        j.click()
        time.sleep(2)

    try:
        click = driver_UP.find_element(By.XPATH, "//div[@class='button']")
        click.click()
    except:
        continue  
    time.sleep(2)
    
    scrolling = True
    while scrolling:
        old_page_source = driver_UP.page_source

        ActionChains(driver_UP).send_keys(Keys.PAGE_DOWN).perform()
        
        time.sleep(3)  
        
        new_page_source = driver_UP.page_source
        
        if new_page_source == old_page_source:
            scrolling = False

    bus_name = driver_UP.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type = driver_UP.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    start_time = driver_UP.find_elements(By.XPATH, "//*[@class='dp-time f-19 d-color f-bold']")
    end_time = driver_UP.find_elements(By.XPATH, "//*[@class='bp-time f-19 d-color disp-Inline']")
    total_duration = driver_UP.find_elements(By.XPATH, "//*[@class='dur l-color lh-24']")
    try:
        rating = driver_UP.find_elements(By.XPATH,"//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")
    except:
        continue
    price = driver_UP.find_elements(By.XPATH, '//*[@class="fare d-block"]')
    seats = driver_UP.find_elements(By.XPATH, "//div[contains(@class, 'seat-left')]")

    for bus in bus_name:
        Bus_names_UP.append(bus.text)
        Route_links.append(link)
        Route_names.append(routes)
    for bus_type_1 in bus_type:
        Bus_types_UP.append(bus_type_1.text)
    for start_time_1 in start_time:
        Start_Time_UP.append(start_time_1.text)
    for end_time_1 in end_time:
        End_Time_UP.append(end_time_1.text)
    for total_duration_1 in total_duration:
        Total_Duration_UP.append(total_duration_1.text)
    for ratings in rating:
        Ratings_UP.append(ratings.text)
    for price_1 in price:
        Prices_UP.append(price_1.text)
    for seats_1 in seats:
        Seats_Available_UP.append(seats_1.text)
        
print("Successfully Completed")
# Out:
# Successfully Completed

# %%
data_UP = {
    'Bus_name': Bus_names_UP,
    'Bus_type': Bus_types_UP,
    'Start_time': Start_Time_UP,
    'End_time': End_Time_UP,
    'Total_duration': Total_Duration_UP,
    'Price': Prices_UP,
    "Seats_Available":Seats_Available_UP,
    "Ratings":Ratings_UP,
    'Route_link': Route_links,
    'Route_name': Route_names
}

df_buses_UP = pd.DataFrame(data_UP)
path=r"C:\Users\bhara\Project\df_buses_UP.csv"
df_buses_UP.to_csv(path,index=False)

# %%
df_buses_UP
# Out:
#                    Bus_name                               Bus_type Start_time  \
# 0          UPSRTC - GND0105             Ordinary Non AC Seater 2+3      14:25
# 1          UPSRTC - LNI0411             Ordinary Non AC Seater 2+3      14:30
# 2          UPSRTC - BLP0030             Rajdhani Non AC Seater 2+3      15:01
# 3          UPSRTC - BLY0109                  Janrath AC Seater 2+2      15:02
# 4          UPSRTC - GND0081             Ordinary Non AC Seater 2+3      15:30
# ..                      ...                                    ...        ...
# 574        UPSRTC - CBG0093             Pink Express AC Seater 2+2      19:16
# 575        UPSRTC - RKD0057             Ordinary Non AC Seater 2+3      19:31
# 576        UPSRTC - RKD0135                  Janrath AC Seater 2+3      22:31
# 577  Vijay Tour and Travels  Bharat Benz A/C Seater /Sleeper (2+1)      15:30
# 578       Mahalaxmi Travels  Bharat Benz A/C Seater /Sleeper (2+1)      17:00
#
# ...

# %% [markdown]
# WB Bus details

# %%
df_WB = pd.read_csv('df_West_Bengal.csv')
df_WB
# Out:
#                                            Route_name  \
# 0                                   Haldia to Kolkata
# 1                      Barasat (West Bengal) to Debra
# 2                    Barasat (West Bengal) to Burdwan
# 3                                 Kolkata to Bakkhali
# 4                                  Kolkata to Purulia
# 5                   Durgapur (West Bengal) to Purulia
# 6                                  Habra to Midnapore
# 7                    Kolkata to Asansol (West Bengal)
# 8     Durgapur (West Bengal) to Barasat (West Bengal)
# 9      Barasat (West Bengal) to Asansol (West Bengal)
# 10                                     Habra to Digha
# 11  Barasat (West Bengal) to Nandakumar (west bengal)
# 12                  Kolkata to Durgapur (West Bengal)
# 13                                     Digha to Habra
# 14                 Midnapore to Barasat (West Bengal)
# 15                    Kolkata to Bolpur (West Bengal)
# ...

# %%
driver_WB = webdriver.Chrome()
Bus_names_WB = []
Bus_types_WB = []
Start_Time_WB = []
End_Time_WB = []
Ratings_WB = []
Total_Duration_WB = []
Prices_WB = []
Seats_Available_WB = []
Route_names = []
Route_links = []

for i,r in df_WB.iterrows():
    link=r["Route_link"]
    routes=r["Route_name"]

    driver_WB.get(link)
    time.sleep(2)  

    x = driver_WB.find_elements(By.XPATH, f"//a[contains(@href, '{link}')]")
    for j in x:
        j.click()
        time.sleep(2)

    try:
        click = driver_WB.find_element(By.XPATH, "//div[@class='button']")
        click.click()
    except:
        continue  
    time.sleep(2)
    
    scrolling = True
    while scrolling:
        old_page_source = driver_WB.page_source

        ActionChains(driver_WB).send_keys(Keys.PAGE_DOWN).perform()
        
        time.sleep(3)  
        
        new_page_source = driver_WB.page_source
        
        if new_page_source == old_page_source:
            scrolling = False

    bus_name = driver_WB.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type = driver_WB.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    start_time = driver_WB.find_elements(By.XPATH, "//*[@class='dp-time f-19 d-color f-bold']")
    end_time = driver_WB.find_elements(By.XPATH, "//*[@class='bp-time f-19 d-color disp-Inline']")
    total_duration = driver_WB.find_elements(By.XPATH, "//*[@class='dur l-color lh-24']")
    try:
        rating = driver_WB.find_elements(By.XPATH,"//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")
    except:
        continue
    price = driver_WB.find_elements(By.XPATH, '//*[@class="fare d-block"]')
    seats = driver_WB.find_elements(By.XPATH, "//div[contains(@class, 'seat-left')]")

    for bus in bus_name:
        Bus_names_WB.append(bus.text)
        Route_links.append(link)
        Route_names.append(routes)
    for bus_type_1 in bus_type:
        Bus_types_WB.append(bus_type_1.text)
    for start_time_1 in start_time:
        Start_Time_WB.append(start_time_1.text)
    for end_time_1 in end_time:
        End_Time_WB.append(end_time_1.text)
    for total_duration_1 in total_duration:
        Total_Duration_WB.append(total_duration_1.text)
    for ratings in rating:
        Ratings_WB.append(ratings.text)
    for price_1 in price:
        Prices_WB.append(price_1.text)
    for seats_1 in seats:
        Seats_Available_WB.append(seats_1.text)
        
print("Successfully Completed")
# Out:
# Successfully Completed

# %%
data_WB = {
    'Bus_name': Bus_names_WB,
    'Bus_type': Bus_types_WB,
    'Start_time': Start_Time_WB,
    'End_time': End_Time_WB,
    'Total_duration': Total_Duration_WB,
    'Price': Prices_WB,
    "Seats_Available":Seats_Available_WB,
    "Ratings":Ratings_WB,
    'Route_link': Route_links,
    'Route_name': Route_names
}

df_buses_WB = pd.DataFrame(data_WB)
path=r"C:\Users\bhara\Project\df_buses_WB.csv"
df_buses_WB.to_csv(path,index=False)

# %%
df_buses_WB
# Out:
#                                              Bus_name             Bus_type  \
# 0   SBSTC-HALDIA - KOLKATA - 15:00 (Haldia Depot) ...  Non AC Seater (2+3)
# 1   SBSTC-HALDIA - KOLKATA - 16:05 (HALDIA DEPOT) ...  Non AC Seater (2+3)
# 2   SBSTC-HALDIA - KOLKATA - ALL STOP - 17:30 (HLD...  Non AC Seater (2+3)
# 3       WBTC (CTC) Habra- Barasat- Haldia - 180|16:45  Non AC Seater (2+3)
# 4   SBSTC-BERHAMPUR - PURULIA - VIA - BANKURA - 08...  Non AC Seater (2+3)
# ..                                                ...                  ...
# 77                                    Satadal Travels     A/C Seater (2+2)
# 78                               Diamond City Service  A/C Executive (2+3)
# 79                              Droupadi City Service     A/C Seater (2+3)
# 80                               Droupadi Bus Service  Non AC Seater (2+3)
# 81                                   Swapna Paribahan  Non AC Seater (2+3)
#
# ...

# %%
df_buses_AP = pd.read_csv('df_buses_ap.csv')
df_buses_KL = pd.read_csv('df_buses_KL.csv')
df_buses_TL = pd.read_csv('df_buses_TL.csv')

# %%
df_all_buses = pd.concat([df_buses_AP, df_buses_KL, df_buses_TL, df_buses_KD, df_buses_RJ,
                          df_buses_SB, df_buses_HM, df_buses_AS, df_buses_UP, df_buses_WB],ignore_index=True)
df_all_buses
# Out:
#                    Bus_name                    Bus_type Start_time End_time  \
# 0                  FRESHBUS   Electric A/C Seater (2+2)      05:50    11:45
# 1                  FRESHBUS   Electric A/C Seater (2+2)      11:05    17:40
# 2           Sri KVR Travels           A/C Sleeper (2+1)      23:35    05:15
# 3       AdIntrCity SmartBus  A/C Seater / Sleeper (2+1)      00:15    06:25
# 4         IntrCity SmartBus  A/C Seater / Sleeper (2+1)      23:50    05:35
# ...                     ...                         ...        ...      ...
# 3488        Satadal Travels            A/C Seater (2+2)      14:55    18:15
# 3489   Diamond City Service         A/C Executive (2+3)      15:10    18:55
# 3490  Droupadi City Service            A/C Seater (2+3)      15:20    18:10
# 3491   Droupadi Bus Service         Non AC Seater (2+3)      16:20    19:10
# 3492       Swapna Paribahan         Non AC Seater (2+3)      16:55    21:25
#
# ...

# %%
path= r"C:\Users\bhara\Project\df_all_buses.csv"
df_all_buses.to_csv(path,index=False)

# %%
df_all_buses["Bus_name"].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3488    False
# 3489    False
# 3490    False
# 3491    False
# 3492    False
# Name: Bus_name, Length: 3493, dtype: bool
